# %% [markdown]
# # Account Setup
#
# BEFORE PROCEEDING WITH CHALLENGES, please run the following code (inserting your specific API key for `<YOUR_TOKEN>` and replacing `<YOUR_INSTANCE>` with the instance associated with your account for QDC 2025).

# %%
from qiskit_ibm_runtime import QiskitRuntimeService

token = "<YOUR_TOKEN>"
instance = "<YOUR_INSTANCE>"

service = QiskitRuntimeService.save_account(
    token=token,
    instance=instance,
    name='qdc-2025',
    overwrite=True
  )

# %% [markdown]
# ## Check the list of Qiskit functions you have access to
#
# You will need access to these Qiskit functions in order to do the corresponding challenges:
#
# - Kipu function for Market Split challenge
# - Q-CTRL Optimization Solver function for Maximum Independent Set challenge
# - Multiverse Singularity function for Multiverse challenge
#
# If you don't have access to any of the functions, please contact the organizers to see if you are already eligible to request for access (for example, NEDO challenge participants can request access).
#
# If you don't have ways to get access to the functions, you please try the Multi-Objective Optimization challenge, which doesn't require Qiskit function access.

# %%
from qiskit_ibm_catalog import QiskitFunctionsCatalog

# Load the Qiskit Functions Catalog
catalog = QiskitFunctionsCatalog(name="qdc-2025")

# You should see a list of Qiskit Functions available to you
# If you encounter the error `QiskitServerlessException: Credentials couldn't be verified`,
# it means your access is not yet active
display(catalog.list())

print("Successfully initialized Qiskit Functions Catalog")
